# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd

from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`

# %%
# your answer here
employee=pd.read_csv('./Employee.csv')
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department.
# ##### Tip : There are 2 ways to do it - one way is with and the other way is without pivot tables. Do it both ways.

# %%
# your answer here-1st way
employee.groupby('Department').agg({'Salary' : 'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# your answer here-2nd way
pivote = pd.pivot_table(employee,
                        values=None,
                        columns=None,
                        index='Department',
                        aggfunc={'Salary': 'mean'}
                        )
pivote
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=None,
                       columns=None,
                       index=['Department','Title'],
                       aggfunc={'Salary': 'mean'})
pivote
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=['Years', 'Salary'],
                       columns=None,
                       index='Title',
                       aggfunc={'Years' : 'sum', 'Salary' : 'sum'}
                       
                       )
pivote
# Out:
#            Salary  Years
# Title
# VP            140     16
# analyst       130      9
# associate     170     12

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=['Salary'],
                       columns=None,
                       index=['Department', 'Title', 'Name'],
                       aggfunc={'Salary' : 'mean'},
                       margins=True,
                       margins_name='Suma_Total'
                       )
pivote
# Out:
#                                 Salary
# Department Title     Name
# HR         VP        Ana     70.000000
#            analyst   David   30.000000
#                      Sonia   35.000000
# IT         VP        Carlos  70.000000
#            analyst   Jose    35.000000
#                      Maria   30.000000
#            associate Pedro   60.000000
# Sales      associate Eva     55.000000
#                      Samuel  55.000000
# Suma_Total                   48.888889

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median,minimum,maximum and standard deviation. Comment your results

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=['Salary'],
                       columns=None,
                       index=['Department', 'Title'],
                       aggfunc={'Salary' : ['mean', 'min', 'max', 'std']},
                       
                       )
pivote
#La std no se puede calcular en todas las observaciones ya que refiere en algunos casos a valores únicos.
# Out:
#                      Salary
#                         max  mean min       std
# Department Title
# HR         VP            70  70.0  70       NaN
#            analyst       35  32.5  30  3.535534
# IT         VP            70  70.0  70       NaN
#            analyst       35  32.5  30  3.535534
#            associate     60  60.0  60       NaN
# Sales      associate     55  55.0  55  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value

# %%
# your answer here
#No se puede llenar, ya que los valores son únicos, el valor máximo, la media y el minimo no se modifican, pues corresponden al mismo dato.

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=['Salary'],
                       columns=None,
                       index=['Department', 'Name'],
                       aggfunc={'Salary' : 'sum'},
                       margins=True,
                       margins_name='Gasto_Total'
                       )
pivote
# Out:
#                     Salary
# Department  Name
# HR          Ana         70
#             David       30
#             Sonia       35
# IT          Carlos      70
#             Jose        35
#             Maria       30
#             Pedro       60
# Sales       Eva         55
#             Samuel      55
# Gasto_Total            440

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary

# %%
# your answer here
pivote = pd.pivot_table(employee,
                       values=['Years', 'Salary'],
                       columns=None,
                       index=['Department', 'Title'],
                       aggfunc={'Years' : 'sum','Salary' : 'mean'},
                       margins=True,
                       margins_name='Gasto_Total'
                       )
pivote
# Out:
#                           Salary  Years
# Department  Title
# HR          VP         70.000000      8
#             analyst    32.500000      6
# IT          VP         70.000000      8
#             analyst    32.500000      3
#             associate  60.000000      7
# Sales       associate  55.000000      5
# Gasto_Total            48.888889     37

# %% [markdown]
# #### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table
#
# #### * Hint: Write a custom function*

# %%
# your answer here--Your custom function here

# %%
# your answer here

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`

# %%
# your answer here
fitbit=pd.read_csv('./Fitbit.csv')
fitbit.head(10)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  08-05-2015            1934    905      0.65       0              1.355
# 1  09-05-2015            3631  18925     14.11       4            611.000
# 2  10-05-2015            3204  14228     10.57       1            602.000
# 3  11-05-2015            2673   6756      5.02       8            749.000
# 4  12-05-2015            2495    502      3.73       1            876.000
# 5  13-05-2015             276    779      5.79      15            726.000
# 6  14-05-2015            2687   5614      4.17       2            782.000
# 7  15-05-2015            2793   8169      6.07      14            801.000
# 8  16-05-2015            4061  19971     14.84      18            532.000
# 9  17-05-2015            3349    852      6.33      12            606.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics
# #### *Hint: Use Pandas functions from previous lectures*

# %%
# your answer here
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Calorie burned          367 non-null    int64
#  2   Steps                   367 non-null    int64
#  3   Distance                367 non-null    float64
#  4   Floors                  367 non-null    int64
#  5   Minutes Sedentary       367 non-null    float64
#  6   Minutes Lightly Active  367 non-null    int64
#  7   Minutes Fairly Active   367 non-null    int64
#  8   Minutes Very Active     367 non-null    int64
#  9   Activity Calories       367 non-null    int64
#  10  MinutesOfSleep          367 non-null    int64
#  11  MinutesOfBeingAwake     367 non-null    int64
#  12  NumberOfAwakings        367 non-null    int64
#  13  LengthOfRestInMinutes   367 non-null    int64
# ...

# %%
# your answer here
fitbit.describe()
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit.corr()
# Out:
#                         Calorie burned     Steps  Distance    Floors  \
# Calorie burned                1.000000  0.255305  0.292790  0.130757
# Steps                         0.255305  1.000000  0.779678  0.306511
# Distance                      0.292790  0.779678  1.000000  0.382940
# Floors                        0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary             0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active        0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active         0.188256  0.303244  0.348113  0.278408
# Minutes Very Active           0.197881  0.571452  0.759310  0.399503
# Activity Calories            -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake           0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings              0.030490  0.106591  0.091095  0.043459
# LengthOfRestInMinutes         0.017460  0.133405  0.134550  0.075864
#
# ...

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
# your answer here
x = fitbit['Minutes Very Active']
y = fitbit['Steps']

plt.figure(figsize=(10,5)) #figgsize=(Ancho, Altura)
plt.scatter(x,y);

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %% [markdown]
# ### your comment here
# La correlación que tienen con base en correlación de Pearson es moderada. Se esperaría que entre más activa fuera una persona
# mas pasos recorriera.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit.corr()
# Out:
#                         Calorie burned     Steps  Distance    Floors  \
# Calorie burned                1.000000  0.255305  0.292790  0.130757
# Steps                         0.255305  1.000000  0.779678  0.306511
# Distance                      0.292790  0.779678  1.000000  0.382940
# Floors                        0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary             0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active        0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active         0.188256  0.303244  0.348113  0.278408
# Minutes Very Active           0.197881  0.571452  0.759310  0.399503
# Activity Calories            -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake           0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings              0.030490  0.106591  0.091095  0.043459
# LengthOfRestInMinutes         0.017460  0.133405  0.134550  0.075864
#
# ...

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x = fitbit['Minutes Sedentary']
y = fitbit['Steps']

plt.figure(figsize=(10,5)) #figgsize=(Ancho, Altura)
plt.scatter(x,y);

# %% [markdown]
# ### Your comment here
# Con base en a correlación de Pearson y al diagrama no se ientifica correlación entre estas variables, es lógico ya que una persona sedentaria pasa más tiempo sin moverse.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# your answer here
fitbit.corr()
# Out:
#                         Calorie burned     Steps  Distance    Floors  \
# Calorie burned                1.000000  0.255305  0.292790  0.130757
# Steps                         0.255305  1.000000  0.779678  0.306511
# Distance                      0.292790  0.779678  1.000000  0.382940
# Floors                        0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary             0.125353  0.076906  0.160632  0.057812
# Minutes Lightly Active        0.209540  0.393010  0.455272 -0.085992
# Minutes Fairly Active         0.188256  0.303244  0.348113  0.278408
# Minutes Very Active           0.197881  0.571452  0.759310  0.399503
# Activity Calories            -0.130758 -0.160568 -0.246853 -0.155532
# MinutesOfSleep                0.011485  0.130986  0.129442  0.069464
# MinutesOfBeingAwake           0.041999  0.124846  0.130447  0.064587
# NumberOfAwakings              0.030490  0.106591  0.091095  0.043459
# LengthOfRestInMinutes         0.017460  0.133405  0.134550  0.075864
#
# ...

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x = fitbit['MinutesOfSleep']
y = fitbit['Steps']

plt.figure(figsize=(10,5)) #figgsize=(Ancho, Altura)
plt.scatter(x,y);

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# your answer here
La correlación entre minutos dormido y los pasos, es casi nula.

# %%
#Print cor_fit

cor_fit=fitbit[['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']]
cor_fit.corr()
# Out:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
# your answer here
cor_fit.corrwith(cor_fit['Steps']).sort_values(ascending=False)
#La variable con la que tiene la mayor correlación es Minutes Very Active
# Out:
# Steps                  1.000000
# Minutes Very Active    0.571452
# Floors                 0.306511
# Calorie burned         0.255305
# MinutesOfSleep         0.130986
# Minutes Sedentary      0.076906
# dtype: float64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`

# %%
# your answer here
time_grades=pd.read_csv('./Time_Grades.csv')

# %%
#Print time_grades
time_grades.head(10)
# Out:
#        Name  Study time  Grade
# 0      Jose           4      4
# 1     Maria           9      7
# 2     David           8      9
# 3     Sonia          10      7
# 4    Samuel          20      9
# 5       Eva           5      3
# 6    Carlos          12      7
# 7     Pedro           6      5
# 8       Ana          18      9
# 9  Gervasio           7      3

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
# your answer here
time_grades.value_counts()
# time_grades['Grade'].value_counts().plot.bar();
# Out:
# Name      Study time  Grade
# Alicia    11          7        1
# Ana       18          9        1
# Carlos    12          7        1
# Cristina  13          8        1
# David     8           9        1
# Eva       5           3        1
# Gemma     7           8        1
# Gervasio  7           3        1
# Jonathan  2           1        1
# Jose      4           4        1
# Maria     9           7        1
# Pedro     6           5        1
# Pilar     3           2        1
# Samuel    20          9        1
# Sonia     10          7        1
# dtype: int64

# %% [markdown]
# #### Is there a correaltion between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# your answer here-Pearson 
time_grades.corr()
# Con base en la correlación de Pearson la relación entre estas variables es fuerte. Teoricamente tiene sentido ya que si estudias
# más tiempo te gardues al final.
# Out:
#             Study time     Grade
# Study time    1.000000  0.798046
# Grade         0.798046  1.000000

# %%
## your answer here-Spearman
time_grades.corr('spearman')
#Con base en la correlación de Pearson la relación entre estas variables es fuerte. Teoricamente tiene sentido ya que si estudias
# más tiempo te gardues al final.
# Out:
#             Study time     Grade
# Study time    1.000000  0.819659
# Grade         0.819659  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
x = time_grades['Study time']
y = time_grades['Grade']

plt.figure(figsize=(10,5)) #figgsize=(Ancho, Altura)
plt.scatter(x,y);

# %%
#your comment here
#La correlación entre estas variables es fuerte y es positiva ya que se espera que si una persona dedica más tiempo a estudiar
#la calificación que obtendrá será mayor.

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %% [markdown]
# #your comment here
# La correlación de Pearson evalúa la relación lineal entre dos variables continuas. Una relación es lineal cuando un cambio en una variable se asocia con un cambio proporcional en la otra variable. Por ejemplo, se puede usar una correlación de Pearson para evaluar si los aumentos de temperatura en sus instalaciones de producción están asociados con una disminución en el espesor de las capas de chocolate.
#
# La correlación de Spearman evalúa la relación monótona entre dos variables continuas u ordinales. En una relación monótona, las variables tienden a cambiar al mismo tiempo, pero no necesariamente a un ritmo constante. El coeficiente de correlación de Spearman se basa en los valores jerarquizados de cada variable y no en los datos sin procesar. La correlación de Spearman suele utilizarse para evaluar relaciones en las que intervienen variables ordinales. Por ejemplo, usted puede usar una correlación de Spearman para evaluar si el orden en que los empleados completan un ejercicio de prueba se relaciona con el número de meses que han estado trabajando en la empresa.
